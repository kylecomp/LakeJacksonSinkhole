# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import Data
inputdata = pd.read_csv('../data/processed/Well2021.csv', parse_dates=['Datetime'],
                        index_col='Datetime', squeeze=True)
#inputdata["DISOLVEDO2_%sat"].loc[(inputdata['DISOLVEDO2_%sat']>0.0025)] = 0

# %%
Zoom1=inputdata.loc['20210502':'20210810']
hydrodata = Zoom1[["DEPTH_m", "TEMP_C", "Rain_mmTotal", "PH", "SPECIFICCONDUCTIVITY_milisiemensPercm", "TOTALDISSOLVEDSOLIDS_gramPerLiter", "DISOLVEDO2_%sat"]]
hydrodata.plot(figsize=(15, 8), subplots=True)
plt.ylabel('Water Level');
plt.xlabel('Time [daily data]');

# %%
Zoom2=inputdata.loc['20210814':'20211114']
hydrodata2 = Zoom2[["DEPTH_m", "TEMP_C", "Rain_mmTotal", "PH", "SPECIFICCONDUCTIVITY_milisiemensPercm", "TOTALDISSOLVEDSOLIDS_gramPerLiter", "DISOLVEDO2_%sat"]]
hydrodata2.plot(figsize=(15, 8), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E3339A908>,
# ...
#       dtype=object)

# %%
Zoom3=inputdata.loc['20211114':'20211212']
hydrodata3 = Zoom3[["DEPTH_m", "TEMP_C", "Rain_mmTotal", "PH", "SPECIFICCONDUCTIVITY_milisiemensPercm", "TOTALDISSOLVEDSOLIDS_gramPerLiter", "DISOLVEDO2_%sat"]]
hydrodata3.plot(figsize=(15, 8), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E3BCEC208>,
# ...
#       dtype=object)

# %%
Zoom4=inputdata.loc['20211215':'20220103']
hydrodata4 = Zoom4[["DEPTH_m", "TEMP_C", "Rain_mmTotal", "PH", "SPECIFICCONDUCTIVITY_milisiemensPercm", "TOTALDISSOLVEDSOLIDS_gramPerLiter", "DISOLVEDO2_%sat"]]
hydrodata4.plot(figsize=(15, 8), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E3E5AD888>,
# ...
#       dtype=object)
