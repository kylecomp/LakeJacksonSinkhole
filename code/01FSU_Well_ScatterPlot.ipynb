# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %%
wq_df = pd.read_csv('../data/FSUWell_FebMar_WQ.csv', parse_dates=['Datatime_Collection'])
wq_df = wq_df.iloc[:-3]

# %%
wq_df
# Out:
#         ID Datatime_Collection  Li      Na    NH4       K     Mg       Ca  \
# 0   FW100A                 NaT   0  20.554  1.313  4.8590  2.124   30.762
# 1   FW100B                 NaT   0  19.351  1.190  4.4000  2.291   38.636
# 2   FW100C                 NaT   0  23.277  1.383  5.4860  2.216   34.128
# 3    FW101 2022-02-03 17:20:00   0  19.929  1.255  5.3470  1.940   28.456
# 4    FW102 2022-02-04 10:45:00   0  20.288  1.197  5.1000  2.117   32.874
# 5    FW103 2022-02-05 12:10:00   0  17.335  0.894  4.1830  2.651   49.071
# 6    FW104 2022-02-06 18:40:00   0  11.149  0.454  2.4660  3.369   66.684
# 7    FW105 2022-02-07 13:40:00   0   7.909  0.209  1.4090  4.350   90.422
# 8    FW106 2022-02-08 11:40:00   0   6.577  0.103  1.8280  4.240   85.823
# 9    FW107 2022-02-09 16:00:00   0   6.049  0.156  0.1325  3.903   77.680
# 10   FW108 2022-02-10 11:20:00   0   5.850  0.000  0.8390  4.250   85.525
# 11   FW109 2022-02-11 10:45:00   0   5.325  0.000  0.8250  4.116   83.670
# ...

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(wq_df, alpha = 1, figsize = (20, 20))
# Out:
# array([[<AxesSubplot:xlabel='Li', ylabel='Li'>,
#         <AxesSubplot:xlabel='Na', ylabel='Li'>,
#         <AxesSubplot:xlabel='NH4', ylabel='Li'>,
#         <AxesSubplot:xlabel='K', ylabel='Li'>,
#         <AxesSubplot:xlabel='Mg', ylabel='Li'>,
#         <AxesSubplot:xlabel='Ca', ylabel='Li'>,
#         <AxesSubplot:xlabel='F', ylabel='Li'>,
#         <AxesSubplot:xlabel='Cl', ylabel='Li'>,
#         <AxesSubplot:xlabel='NO2', ylabel='Li'>,
#         <AxesSubplot:xlabel='Br', ylabel='Li'>,
#         <AxesSubplot:xlabel='NO3', ylabel='Li'>,
#         <AxesSubplot:xlabel='PO4', ylabel='Li'>,
#         <AxesSubplot:xlabel='SO4', ylabel='Li'>,
#         <AxesSubplot:xlabel='EC', ylabel='Li'>,
#         <AxesSubplot:xlabel='TDS', ylabel='Li'>,
#         <AxesSubplot:xlabel='pH', ylabel='Li'>,
#         <AxesSubplot:xlabel='pOH', ylabel='Li'>,
#         <AxesSubplot:xlabel='TotalAlk(mg/L_asCaCO3)', ylabel='Li'>],
#        [<AxesSubplot:xlabel='Li', ylabel='Na'>,
# ...
