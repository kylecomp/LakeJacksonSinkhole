# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../data/processed/WakullaSprings.CSV', parse_dates=['datetime'], delimiter = ',', header = 0, index_col = "datetime")

# %%
df2=pd.read_csv('../data/raw/NWFWMD_Wakulla_Discharge.CSV', parse_dates=['Timestamp (UTC)'], delimiter = ',', header = 0, index_col = "Timestamp (UTC)")
df2.index.name='datetime'

# %%
df.index
# Out:
# Index([2017-01-27 10:51:00-05:00, 2017-01-27 11:00:00-05:00,
#        2017-01-27 11:15:00-05:00, 2017-01-27 11:30:00-05:00,
#        2017-01-27 11:45:00-05:00, 2017-01-27 12:00:00-05:00,
#        2017-01-27 12:15:00-05:00, 2017-01-27 12:30:00-05:00,
#        2017-01-27 12:45:00-05:00, 2017-01-27 13:00:00-05:00,
#        ...
#        2021-12-26 17:00:00-05:00, 2021-12-26 17:15:00-05:00,
#        2021-12-26 17:30:00-05:00, 2021-12-26 17:45:00-05:00,
#        2021-12-26 18:00:00-05:00, 2021-12-26 18:15:00-05:00,
#        2021-12-26 18:30:00-05:00, 2021-12-26 18:45:00-05:00,
#        2021-12-26 19:00:00-05:00, 2021-12-26 19:15:00-05:00],
#       dtype='object', name='datetime', length=171956)

# %%
df3=pd.merge_asof(df, df2, on='datetime',  left_on=None, right_on=None)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-18-1d5697817b35> in <module>
# ----> 1 df3=pd.merge_asof(df, df2, on='datetime',  left_on=None, right_on=None)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     537         tolerance=tolerance,
#     538         allow_exact_matches=allow_exact_matches,
# --> 539         direction=direction,
#     540     )
#     541     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, axis, suffixes, copy, fill_method, how, tolerance, allow_exact_matches, direction)
#    1552             how=how,
# ...

# %%
Nitrate=df.Nitrate_Nitrite[df.Precip_in>=0]
Precip=df.Precip_in[df.Precip_in>=0]

# %%
Turbidity
# Out:
# datetime
# 2017-01-27 11:00:00-05:00    0.0
# 2017-01-27 11:15:00-05:00    0.1
# 2017-01-27 11:30:00-05:00    0.1
# 2017-01-27 11:45:00-05:00    0.1
# 2017-01-27 12:00:00-05:00    0.1
#                             ...
# 2019-06-29 23:30:00-04:00    0.0
# 2019-06-29 23:45:00-04:00    0.0
# 2019-06-30 00:00:00-04:00    0.0
# 2019-06-30 00:15:00-04:00    0.0
# 2019-06-30 00:30:00-04:00    0.0
# Name: Turdbidity, Length: 69853, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(2,sharex=True, figsize=(15,15))

ax1.plot(df.Gage_Height_ft)
ax2.plot(df.Nitrate_Nitrite, color ='red')

# %%
fig, (ax1, ax2) = plt.subplots(2,sharex=True, figsize=(15,15))

ax1.plot(Precip)
ax2.plot(Nitrate, color ='red')
